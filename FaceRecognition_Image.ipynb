# %% [markdown]
# # Getting Embeddings

# %%
import torch
from torch.utils.data import DataLoader
from torchvision import transforms, datasets
import numpy as np
import pandas as pd
import torch.nn as nn
import cv2
from facenet_pytorch import MTCNN, InceptionResnetV1
from PIL import Image

# The model is running on CPU, since it is already pre-trained and doesnt require GPU
device = torch.device('cpu') 
print('Running on device: {}'.format(device))

#Define MTCNN module
#Since MTCNN is a collection of neural nets and other code, 
#The device must be passed in the following way to enable copying of objects when needed internally.
mtcnn = MTCNN(
    image_size=160, margin=0, min_face_size=20,
    thresholds=[0.6, 0.7, 0.7], factor=0.709, prewhiten=True,
    device=device
)
#Function takes 2 vectors 'a' and 'b'
#Returns the cosine similarity according to the definition of the dot product
def cos_sim(a, b):
    dot_product = np.dot(a, b)
    norm_a = np.linalg.norm(a)
    norm_b = np.linalg.norm(b)
    return dot_product / (norm_a * norm_b)

#cos_sim returns real numbers,where negative numbers have different interpretations.
#So we use this function to return only positive values.
def cos(a,b):
    minx = -1 
    maxx = 1
    return (cos_sim(a,b)- minx)/(maxx-minx)

# Define Inception Resnet V1 module (GoogLe Net)
resnet = InceptionResnetV1(pretrained='vggface2').eval().to(device)

# Define a dataset and data loader
dataset = datasets.ImageFolder('Film/gmrit')
dataset.idx_to_class = {i:c for c, i in dataset.class_to_idx.items()}
loader = DataLoader(dataset, collate_fn=lambda x: x[0])

#Perfom MTCNN facial detection
#Detects the face present in the image and prints the probablity of face detected in the image.
aligned = []
names = []
for x, y in loader:
    x_aligned, prob = mtcnn(x, return_prob=True)
    if x_aligned is not None:
        print('Face detected with probability: {:8f}'.format(prob))
        aligned.append(x_aligned)
        names.append(dataset.idx_to_class[y])

# Calculate the 512 face embeddings
aligned = torch.stack(aligned).to(device)
embeddings = resnet(aligned).cpu()

# Print distance matrix for classes.
#The embeddings are plotted in space and cosine distace is measured.
cos_sim = nn.CosineSimilarity(dim=-1, eps=1e-6)
for i in range(0,len(names)):
    emb=embeddings[i].unsqueeze(0)
    # The cosine similarity between the embeddings is given by 'dist'.
    dist =cos(embeddings[0],emb)  
        
dists = [[cos(e1,e2).item() for e2 in embeddings] for e1 in embeddings]
# The print statement below is
#Helpful for analysing the results and for determining the value of threshold.
print(pd.DataFrame(dists, columns=names, index=names))
# Out:
# Running on device: cpu
# C:\Users\91951\anaconda3\lib\site-packages\torch\nn\functional.py:780: UserWarning: Note that order of the arguments: ceil_mode and return_indices will changeto match the args list in nn.MaxPool2d in a future release.
#   warnings.warn("Note that order of the arguments: ceil_mode and return_indices will change"
# Face detected with probability: 0.999954
# Face detected with probability: 0.999999
# Face detected with probability: 0.999957
# Face detected with probability: 0.999903
# Face detected with probability: 0.999990
# Face detected with probability: 0.999992
# Face detected with probability: 0.998944
# Face detected with probability: 0.999616
# Face detected with probability: 1.000000
# Face detected with probability: 0.999945
# Face detected with probability: 0.999679
# Face detected with probability: 0.999998
# Face detected with probability: 0.999909
# Face detected with probability: 0.999924
# Face detected with probability: 0.999765
# Face detected with probability: 0.999952
# Face detected with probability: 0.999982
# Face detected with probability: 0.999894
# Face detected with probability: 0.999518
# Face detected with probability: 1.000000
# Face detected with probability: 0.999743
# Face detected with probability: 0.999999
# Face detected with probability: 0.999951
# Face detected with probability: 0.999994
# Face detected with probability: 0.999995
# Face detected with probability: 0.999992
# Face detected with probability: 0.979022
# Face detected with probability: 0.992869
# Face detected with probability: 0.999892
# Face detected with probability: 0.999892
# Face detected with probability: 0.999611
# Face detected with probability: 0.999871
# Face detected with probability: 0.999907
# Face detected with probability: 0.999970
# Face detected with probability: 0.999992
# Face detected with probability: 0.999999
# Face detected with probability: 0.999986
# Face detected with probability: 0.999905
# Face detected with probability: 0.999903
# Face detected with probability: 0.999743
# Face detected with probability: 0.999999
# Face detected with probability: 0.999917
# Face detected with probability: 0.999217
# Face detected with probability: 0.999985
# Face detected with probability: 0.999986
# Face detected with probability: 0.999873
# Face detected with probability: 0.999989
# Face detected with probability: 0.999610
# Face detected with probability: 0.999994
# Face detected with probability: 0.999998
# Face detected with probability: 0.999972
# Face detected with probability: 0.999966
# Face detected with probability: 0.996959
# Face detected with probability: 1.000000
# Face detected with probability: 0.999999
# Face detected with probability: 0.999993
# Face detected with probability: 0.999981
# Face detected with probability: 0.999981
# Face detected with probability: 0.999981
# Face detected with probability: 0.999990
# Face detected with probability: 0.999599
# Face detected with probability: 1.000000
# Face detected with probability: 0.999879
# Face detected with probability: 0.999949
# Face detected with probability: 0.999965
# Face detected with probability: 0.999763
# Face detected with probability: 0.997813
# Face detected with probability: 0.997226
# Face detected with probability: 0.999462
# Face detected with probability: 0.997631
# Face detected with probability: 0.992089
# Face detected with probability: 0.990315
# Face detected with probability: 0.999992
# Face detected with probability: 0.999832
# Face detected with probability: 0.999999
# Face detected with probability: 0.999980
# Face detected with probability: 0.999999
# Face detected with probability: 0.999928
# Face detected with probability: 0.999994
# Face detected with probability: 0.999999
# Face detected with probability: 0.999998
# Face detected with probability: 0.999879
# Face detected with probability: 0.999974
# Face detected with probability: 0.999987
# Face detected with probability: 0.999887
# Face detected with probability: 0.999999
# Face detected with probability: 0.999957
# Face detected with probability: 0.999999
# Face detected with probability: 0.999927
# Face detected with probability: 0.999999
# Face detected with probability: 0.999933
# Face detected with probability: 0.999984
# Face detected with probability: 0.999923
# Face detected with probability: 1.000000
# Face detected with probability: 0.999985
# Face detected with probability: 1.000000
# Face detected with probability: 0.999987
# Face detected with probability: 1.000000
# Face detected with probability: 0.999996
# Face detected with probability: 1.000000
# Face detected with probability: 0.999993
# Face detected with probability: 0.998895
# Face detected with probability: 0.999984
# Face detected with probability: 0.999952
# Face detected with probability: 1.000000
# Face detected with probability: 1.000000
# Face detected with probability: 0.998754
# Face detected with probability: 0.999998
# Face detected with probability: 0.999998
# Face detected with probability: 1.000000
# Face detected with probability: 1.000000
# Face detected with probability: 0.999999
# Face detected with probability: 0.999996
# Face detected with probability: 0.999932
# Face detected with probability: 0.999965
# Face detected with probability: 0.999844
# Face detected with probability: 0.999853
# Face detected with probability: 0.999999
# Face detected with probability: 0.999992
# Face detected with probability: 0.999992
# Face detected with probability: 0.999996
# Face detected with probability: 0.999962
# Face detected with probability: 0.999977
# Face detected with probability: 0.827005
# Face detected with probability: 0.999939
# Face detected with probability: 0.998173
# Face detected with probability: 0.999989
# Face detected with probability: 0.723659
# Face detected with probability: 0.999993
# Face detected with probability: 0.999997
# Face detected with probability: 0.999965
# Face detected with probability: 0.999998
# Face detected with probability: 0.999996
# Face detected with probability: 0.999997
# Face detected with probability: 0.999998
# Face detected with probability: 0.999986
# Face detected with probability: 0.999933
# Face detected with probability: 0.999983
# Face detected with probability: 0.999999
# Face detected with probability: 0.999999
# Face detected with probability: 0.999995
# Face detected with probability: 0.999999
# Face detected with probability: 0.999996
# Face detected with probability: 1.000000
# Face detected with probability: 0.999948
# Face detected with probability: 0.999986
# Face detected with probability: 0.999980
# Face detected with probability: 0.999998
# Face detected with probability: 0.979362
# Face detected with probability: 0.999763
# Face detected with probability: 0.995293
# Face detected with probability: 0.999636
# Face detected with probability: 0.999343
# Face detected with probability: 0.980106
# Face detected with probability: 0.999954
# Face detected with probability: 0.999083
# Face detected with probability: 0.999913
# Face detected with probability: 0.999606
#             20341A0501  20341A0501  20341A0501  20341A0501  20341A0501  \
# 20341A0501    1.000000    0.887216    0.933919    0.903877    0.949897
# 20341A0501    0.887216    1.000000    0.907403    0.955552    0.899446
# 20341A0501    0.933919    0.907403    1.000000    0.872137    0.940780
# 20341A0501    0.903877    0.955552    0.872137    1.000000    0.909373
# 20341A0501    0.949897    0.899446    0.940780    0.909373    1.000000
# ...                ...         ...         ...         ...         ...
# 20341a0530    0.816318    0.740790    0.816802    0.760515    0.811529
# 20341a0530    0.813380    0.713447    0.794358    0.765421    0.825447
# 20341a0530    0.779036    0.727084    0.798624    0.752780    0.800739
# 20341a0530    0.778657    0.807931    0.803461    0.800268    0.809572
# 20341a0530    0.777488    0.772832    0.781125    0.794851    0.822264
#
#             20341A0501  20341A0502  20341A0502  20341A0502  20341A0502  ...  \
# 20341A0501    0.877931    0.756959    0.701035    0.761592    0.739181  ...
# 20341A0501    0.947752    0.741375    0.711275    0.694254    0.657795  ...
# 20341A0501    0.893989    0.762030    0.714679    0.744923    0.701733  ...
# 20341A0501    0.934683    0.750508    0.717974    0.732750    0.713711  ...
# 20341A0501    0.861918    0.774764    0.745164    0.766098    0.751532  ...
# ...                ...         ...         ...         ...         ...  ...
# 20341a0530    0.772069    0.743772    0.706771    0.745789    0.798390  ...
# 20341a0530    0.708728    0.736021    0.714259    0.716282    0.789926  ...
# 20341a0530    0.752759    0.765102    0.721771    0.787504    0.818720  ...
# 20341a0530    0.773730    0.775071    0.741213    0.767668    0.799651  ...
# 20341a0530    0.741332    0.726101    0.710186    0.700513    0.763151  ...
#
#             20341a0530  20341a0530  20341a0530  20341a0530  20341a0530  \
# 20341A0501    0.760458    0.827470    0.730623    0.789188    0.843960
# 20341A0501    0.747430    0.768624    0.705701    0.717951    0.811623
# 20341A0501    0.784594    0.827094    0.747619    0.756221    0.841330
# 20341A0501    0.751353    0.789746    0.700519    0.725515    0.827736
# 20341A0501    0.785941    0.832493    0.764772    0.796738    0.855199
# ...                ...         ...         ...         ...         ...
# 20341a0530    0.851409    0.862907    0.828463    0.849893    0.875184
# 20341a0530    0.893077    0.947183    0.858654    0.880619    0.892351
# 20341a0530    0.874088    0.887873    0.811642    0.893113    0.879619
# 20341a0530    0.877027    0.882122    0.790380    0.803447    0.886690
# 20341a0530    0.906299    0.923428    0.868338    0.865267    0.899273
#
#             20341a0530  20341a0530  20341a0530  20341a0530  20341a0530
# 20341A0501    0.816318    0.813380    0.779036    0.778657    0.777488
# 20341A0501    0.740790    0.713447    0.727084    0.807931    0.772832
# 20341A0501    0.816802    0.794358    0.798624    0.803461    0.781125
# 20341A0501    0.760515    0.765421    0.752780    0.800268    0.794851
# 20341A0501    0.811529    0.825447    0.800739    0.809572    0.822264
# ...                ...         ...         ...         ...         ...
# 20341a0530    1.000000    0.889424    0.912107    0.838225    0.906554
# 20341a0530    0.889424    1.000000    0.902062    0.854014    0.917231
# 20341a0530    0.912107    0.902062    1.000000    0.863477    0.860737
# 20341a0530    0.838225    0.854014    0.863477    1.000000    0.877383
# 20341a0530    0.906554    0.917231    0.860737    0.877383    1.000000
#
# [158 rows x 158 columns]

# %% [markdown]
# # Face Recognition from Images

# %%
from facenet_pytorch import MTCNN, InceptionResnetV1,extract_face
from PIL import Image,ImageDraw
import torch
import cv2
import torch.nn as nn
import pandas as pd
#Takes 2 vectors 'a' and 'b'.
#Return the cosine similarity according to the definition of the dot product.
def cos_sim(a, b):
    dot_product = np.dot(a, b)
    norm_a = np.linalg.norm(a)
    norm_b = np.linalg.norm(b)
    return dot_product / (norm_a * norm_b)

#cos_sim returns real numbers,where negative numbers have different interpretations.
#So we use this function to return only positive values.
def cos(a,b):   
    minx = -1 
    maxx = 1
    return (cos_sim(a,b)- minx)/(maxx-minx)


#This is the function for doing face recognition.
def verify(embedding): 
    f1=open("./Attendance.csv", "w")
    f1.truncate()
    lst = []
    pst = []
    dict1 = {}
#     dict1 = {'Name': listItems, 'Attended': None, 'Time': None}
#     df = pd.DataFrame(dict1)
#     df.to_csv("./Attendance.csv")
    for i,k in enumerate(embeddings):
        for j,l in enumerate(embedding):
            #Computing Cosine distance.
            dist =cos(k,l)
               
            # Chosen threshold is 0.85. 
            #Threshold is determined after seeing the table in the previous cell.
            if dist > 0.85:
                #Name of the person identified is printed on the screen, as well as below the detecetd face (below the rectangular box).
                text=names[i]
                cv2.putText(im, text,(boxes[j][0].astype(int) ,boxes[j][3].astype(int) + 17), cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (255,255,255), 2)
                print(text)
                lst.append(text)
                pst.append(pd.to_datetime('today'))
#                 dict1 = {'Name': lst,'time': pst}
        df = pd.DataFrame(lst)
        df1 = df.drop_duplicates()
        df1.to_csv("./Attendance.csv")
                
                
#Model running on CPU           
device = torch.device('cpu')  

#Define Inception Resnet V1 module (GoogLe Net)
resnet = InceptionResnetV1(pretrained='vggface2').eval().to('cpu')

#Define MTCNN module
#Since MTCNN is a collection of neural nets and other code, 
#The device must be passed in the following way to enable copying of objects when needed internally.
#'keep_all' is kept True. All the faces present in the image will be detected.
mtcnn = MTCNN(
    image_size=160, margin=0, min_face_size=20,
    thresholds=[0.6, 0.7, 0.7], factor=0.709, prewhiten=True,
    device=device,keep_all=True
)

#Get cropped and prewhitened image tensor of PIL image.
img = Image.open('Film/gmrit/test2.jpeg')
img_cropped = mtcnn(img)
boxes,prob=mtcnn.detect(img)
img_draw = img.copy()
draw = ImageDraw.Draw(img_draw)

#Rectangular boxes are drawn on faces present in the image.
#The detected and cropped faces are then saved.
for i, box in enumerate(boxes):
    draw.rectangle(box.tolist())
    extract_face(img, box, save_path='Film/Test/Cropped_Face_{}.jpg'.format(i))
img_draw.save('Film/Test/Faces_Detected.jpg')

#Calculate embeddings of each cropped face and print it.


im=cv2.imread('Film/Test/Faces_Detected.jpg')
img_embedding = resnet(img_cropped)
print(img_embedding)

#print(size of img_embedding)

print(img_embedding.size())


#Call function verify. 
#Identify the person with the help of embeddings.
cos_sim = nn.CosineSimilarity(dim=-1, eps=1e-6)
verify(img_embedding)


#'Image' window opens.
#The PIL image now have rectangular boxes on detected faces.
#The identified faces have their respective name below the box.
cv2.imshow("Image",im)
k=cv2.waitKey(0)

#13 is for 'Enter' key.
#If 'Enter' key is pressed, all the windows are made to close forcefully.
if k==13:
    cv2.destroyAllWindows()
# Out:
# tensor([[ 0.0083,  0.0293, -0.0583,  ...,  0.0094, -0.0276, -0.0026],
#         [-0.0083, -0.0600, -0.0645,  ...,  0.0147, -0.0628,  0.0435],
#         [-0.0075, -0.0666, -0.0683,  ...,  0.0309, -0.0439,  0.0297],
#         ...,
#         [ 0.0493, -0.0478, -0.0281,  ..., -0.0168, -0.0710, -0.0260],
#         [ 0.0924,  0.0166, -0.0302,  ..., -0.0378, -0.0203, -0.0030],
#         [ 0.0780, -0.0005,  0.0201,  ..., -0.0541, -0.1452, -0.0031]],
#        grad_fn=<DivBackward0>)
# torch.Size([25, 512])
# 20341A0501
# 20341A0501
# 20341A0501
# 20341A0501
# 20341A0501
# 20341A0501
# 20341A0502
# 20341A0502
# 20341A0502
# 20341A0502
# 20341A0502
# 20341A0502
# 20341A0503
# 20341A0503
# 20341A0503
# 20341A0504
# 20341A0504
# 20341A0504
# 20341A0504
# 20341A0507
# 20341A0507
# 20341A0507
# 20341A0507
# 20341A0507
# 20341A0507
# 20341A0508
# 20341A0508
# 20341A0509
# 20341A0509
# 20341A0509
# 20341A0510
# 20341A0511
# 20341A0511
# 20341A0511
# 20341A0511
# 20341A0511
# 20341A0512
# 20341A0516
# 20341A0518
# 20341A0518
# 20341A0518
# 20341A0518
# 20341A0518
# 20341A0518
# 20341A0518
# 20341A0518
# 20341A0519
# 20341A0519
# 20341A0519
# 20341A0520
# 20341A0521
# 20341A0521
# 20341A0521
# 20341A0521
# 20341A0521
# 20341A0527
# 20341A0527
# 20341A0527
# 20341A0527
# 20341A0527
# 20341A0527
# 20341A0527
# 20341A0527
# 20341A0527
# 20341A0527
# 20341A0527
# 20341A0527
# 20341A0527
# 20341A0529
# 20341A0529
# 20341A0529
# 20341A0529
# 20341A0529
# 20341A0529
# 20341A0529
# 20341a0523
# 20341a0523
# 20341a0523
# 20341a0523
# 20341a0523
# 20341a0523
# 20341a0523
# 20341a0524
# 20341a0524
# 20341a0524
# 20341a0524
# 20341a0524
# 20341a0524
# 20341a0526
# 20341a0526
# 20341a0526
# 20341a0526
# 20341a0526
# 20341a0526
# 20341a0526
# 20341a0526
# 20341a0526
# 20341a0526
# 20341a0528
# 20341a0528
# 20341a0528
# 20341a0528
# 20341a0528
# 20341a0528
# 20341a0528
# 20341a0528
# 20341a0528
# 20341a0528
# 20341a0528
# 20341a0528
# 20341a0528
# 20341a0528
# 20341a0528
# 20341a0528
# 20341a0528
# 20341a0528
# 20341a0528
# 20341a0528
# 20341a0528
# 20341a0530
# 20341a0530
# 20341a0530
# 20341a0530
# 20341a0530
# 20341a0530
# 20341a0530
